# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib

# %%
data_path = pathlib.Path(".")
data = pd.read_csv(data_path / "listings_with_scores.csv")

cols = ["source_id","url","image_count","luxury_bathroom","luxury_bedroom","luxury_floor_plan","luxury_kitchen","luxury_living_room","luxury_toilet","brightness_bathroom","brightness_bedroom","brightness_floor_plan","brightness_kitchen","brightness_living_room","brightness_toilet","modernity_bathroom","modernity_bedroom","modernity_floor_plan","modernity_kitchen","modernity_living_room","modernity_toilet"]
data[cols]
# Out:
#       source_id                                                url  \
# 0      20277732  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
# 1      20332918  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
# 2      20344616  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_2...
# 3      78385243  https://suumo.jp/ms/chuko/tokyo/sc_adachi/nc_7...
# 4      78151350  https://suumo.jp/ms/chuko/tokyo/sc_bunkyo/nc_7...
# ...         ...                                                ...
# 1592   20149614  https://suumo.jp/ms/chuko/tokyo/sc_sumida/nc_2...
# 1593   20150066  https://suumo.jp/ms/chuko/tokyo/sc_sumida/nc_2...
# 1594   20173930  https://suumo.jp/ms/chuko/tokyo/sc_taito/nc_20...
# 1595   20353994  https://suumo.jp/ms/chuko/tokyo/sc_taito/nc_20...
# 1596   20354046  https://suumo.jp/ms/chuko/tokyo/sc_taito/nc_20...
#
#       image_count  luxury_bathroom  luxury_bedroom  luxury_floor_plan  \
# 0              24         0.457813        0.347656            -1000.0
# ...

# %%
data_path = pathlib.Path(".")
data_images = pd.read_csv(data_path / "images_cleaned.csv")
cols = ["source_id","listing_url","image_url","image_path","room_type","scoring_dict"]
data_images[cols]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 data_path = pathlib.Path(".")
#       2 data_images = pd.read_csv(data_path / "images_cleaned.csv")
# ----> 3 cols = ["source_id","listing_url","image_url",image_path,room_type,scoring_dict]
#       4 data_images[cols]
#
# NameError: name 'image_path' is not defined
